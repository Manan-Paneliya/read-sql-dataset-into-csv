# %% [markdown]
# # Read SQL file into CSV

# %% [markdown]
# ### 1) Download world.sql dataset

# %% [markdown]
# ### 2) Start Apache and MySql from XAMPP control panel (If XAMPP install otherwise download and install)

# %% [markdown]
#    <img src="xampp.jpg" alt="An example image">

# %% [markdown]
# ### 3) make database on localhost/phpmyadmin/

# %% [markdown]
#    <img src="php.jpg" alt="An example image">

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 4) install mysql.connector

# %%
pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.9 MB 435.7 kB/s eta 0:00:28
#      --------------------------------------- 0.0/11.9 MB 279.3 kB/s eta 0:00:43
#      --------------------------------------- 0.0/11.9 MB 279.3 kB/s eta 0:00:43
#      --------------------------------------- 0.1/11.9 MB 297.7 kB/s eta 0:00:40
#      --------------------------------------- 0.1/11.9 MB 348.6 kB/s eta 0:00:34
#      --------------------------------------- 0.1/11.9 MB 399.4 kB/s eta 0:00:30
#      --------------------------------------- 0.1/11.9 MB 425.3 kB/s eta 0:00:28
#      --------------------------------------- 0.1/11.9 MB 425.3 kB/s eta 0:00:28
#       -------------------------------------- 0.2/11.9 MB 364.0 kB/s eta 0:00:33
#       -------------------------------------- 0.2/11.9 MB 380.0 kB/s eta 0:00:31
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host = 'localhost', user = 'root', password = '', database = 'world')

# %%
city = pd.read_sql_query("SELECT * FROM city", conn)
country = pd.read_sql_query("SELECT * FROM country", conn)
country_language = pd.read_sql_query("SELECT * FROM countrylanguage", conn)
# Out:
# C:\Users\91704\AppData\Local\Temp\ipykernel_17688\1622992880.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   city = pd.read_sql_query("SELECT * FROM city", conn)
# C:\Users\91704\AppData\Local\Temp\ipykernel_17688\1622992880.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   country = pd.read_sql_query("SELECT * FROM country", conn)
# C:\Users\91704\AppData\Local\Temp\ipykernel_17688\1622992880.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %%
city.head()
# Out:
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200
